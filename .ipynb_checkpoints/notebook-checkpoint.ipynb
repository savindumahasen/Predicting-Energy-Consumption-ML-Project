# %% [markdown]
# # Predicting Energy Consuption Machine Learning Project

# %%
##  import the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
## Load the train set
train_set=pd.read_csv("train_energy_data.csv")
train_set.head()
# Out:
#   Building Type  Square Footage  Number of Occupants  Appliances Used  \
# 0   Residential            7063                   76               10
# 1    Commercial           44372                   66               45
# 2    Industrial           19255                   37               17
# 3   Residential           13265                   14               41
# 4    Commercial           13375                   26               18
#
#    Average Temperature Day of Week  Energy Consumption
# 0                29.84     Weekday             2713.95
# 1                16.72     Weekday             5744.99
# 2                14.30     Weekend             4101.24
# 3                32.82     Weekday             3009.14
# 4                11.92     Weekday             3279.17

# %%
train_set.sample(10)
# Out:
#     Building Type  Square Footage  Number of Occupants  Appliances Used  \
# 9     Residential           17467                   42               36
# 365   Residential           19629                   21               39
# 666    Industrial           18523                   79               45
# 312    Industrial           23361                   26               26
# 301    Industrial           46507                   41               30
# 707   Residential            6871                   26               19
# 772    Industrial           14359                   69               40
# 321    Commercial           22026                   70               12
# 641   Residential           21081                    5               25
# 807    Industrial           12675                    2               47
#
#      Average Temperature Day of Week  Energy Consumption
# 9                  28.84     Weekday             3419.13
# 365                12.37     Weekday             3459.59
# 666                22.39     Weekday             5054.19
# 312                29.05     Weekend             4302.81
# 301                22.60     Weekday             5772.35
# 707                33.73     Weekday             2364.90
# 772                19.94     Weekday             4658.27
# 321                21.58     Weekend             3933.39
# 641                26.29     Weekend             2972.61
# 807                11.93     Weekend             4034.11

# %%
## check the type of train set
type(train_set)
# Out:
# pandas.core.frame.DataFrame

# %%
## check the features of dataset
train_set.keys()
# Out:
# Index(['Building Type', 'Square Footage', 'Number of Occupants',
#        'Appliances Used', 'Average Temperature', 'Day of Week',
#        'Energy Consumption'],
#       dtype='object')

# %%
## Get the information of train set
train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Building Type        1000 non-null   object
#  1   Square Footage       1000 non-null   int64
#  2   Number of Occupants  1000 non-null   int64
#  3   Appliances Used      1000 non-null   int64
#  4   Average Temperature  1000 non-null   float64
#  5   Day of Week          1000 non-null   object
#  6   Energy Consumption   1000 non-null   float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 54.8+ KB

# %%
## check the the value counts of the  categorical attributes

# %%
train_set['Building Type'].value_counts()
# Out:
# Building Type
# Residential    347
# Commercial     336
# Industrial     317
# Name: count, dtype: int64

# %%
train_set['Day of Week'].value_counts()
# Out:
# Day of Week
# Weekday    507
# Weekend    493
# Name: count, dtype: int64

# %%
## Summerizing the stat
train_set_describe=train_set.describe()
train_set_describe
# Out:
#        Square Footage  Number of Occupants  Appliances Used  \
# count        1000.000          1000.000000      1000.000000
# mean        25462.388            48.372000        25.606000
# std         14294.554            29.061972        14.105166
# min           560.000             1.000000         1.000000
# 25%         13169.750            22.000000        13.000000
# 50%         25477.000            47.000000        26.000000
# 75%         37446.250            73.250000        38.000000
# max         49997.000            99.000000        49.000000
#
#        Average Temperature  Energy Consumption
# count          1000.000000         1000.000000
# mean             22.611390         4166.252570
# std               7.139943          933.313064
# min              10.050000         1683.950000
# 25%              16.475000         3509.482500
# 50%              22.815000         4175.730000
# 75%              28.850000         4863.850000
# max              34.990000         6530.600000

# %%
## checking the missing values
train_set.isnull().sum()
# Out:
# Building Type          0
# Square Footage         0
# Number of Occupants    0
# Appliances Used        0
# Average Temperature    0
# Day of Week            0
# Energy Consumption     0
# dtype: int64

# %% [markdown]
# ## EDA (Explotary Data Analysis)

# %%
## check correlation  between independent features and dependent feature
train_set_correlation=train_set_describe.corr()
train_set_correlation
# Out:
#                      Square Footage  Number of Occupants  Appliances Used  \
# Square Footage             1.000000            -0.386668        -0.428792
# Number of Occupants       -0.386668             1.000000         0.998921
# Appliances Used           -0.428792             0.998921         1.000000
# Average Temperature       -0.445557             0.997814         0.999783
# Energy Consumption         0.915955            -0.406413        -0.442522
#
#                      Average Temperature  Energy Consumption
# Square Footage                 -0.445557            0.915955
# Number of Occupants             0.997814           -0.406413
# Appliances Used                 0.999783           -0.442522
# Average Temperature             1.000000           -0.453840
# Energy Consumption             -0.453840            1.000000

# %%
## visualize the dataset using  pair plot
import seaborn as sns
sns.pairplot(train_set)

# %%
## check the correlation for each and every independent and  target variable

# %%
## plot the scatterplot for sqaure footage vs Energy consumption

# %%
plt.scatter(train_set['Square Footage'],train_set['Energy Consumption'], color='green')
plt.xlabel('Square Footage')
plt.ylabel('Energy Consumption')
plt.show()

# %%
## plot the scatterplot for Number of Occupants  vs Energy consumption

# %%
plt.scatter(train_set['Number of Occupants'],train_set['Energy Consumption'], color='orange')
plt.xlabel('Square Footage')
plt.ylabel('Energy Consumption')
plt.show()

# %%
## plot the scatterplot for Appliances Used  vs Energy consumption

# %%
plt.scatter(train_set['Appliances Used'], train_set['Energy Consumption'], color='gray')
plt.xlabel('Appliances Used')
plt.ylabel('Energy Consumption')
plt.plot()
# Out:
# []

# %%
## plot the scatterplot for Average Temperaure vs Energy consumption

# %%
plt.scatter(train_set['Average Temperature'], train_set['Energy Consumption'], color='red')
plt.xlabel('Average Temperature')
plt.ylabel('Energy Consumption')
plt.show()

# %%
## represent the above independant and  dependant features correlation in regression plot

# %%
import seaborn as sns
sns.regplot(x="Square Footage", y="Energy Consumption", data=train_set, scatter_kws={'color':'green'}, line_kws={'color':'red'})
# Out:
# <Axes: xlabel='Square Footage', ylabel='Energy Consumption'>

# %%
train_set.keys()
# Out:
# Index(['Building Type', 'Square Footage', 'Number of Occupants',
#        'Appliances Used', 'Average Temperature', 'Day of Week',
#        'Energy Consumption'],
#       dtype='object')

# %%
import seaborn as sns
sns.regplot(x="Number of Occupants", y="Energy Consumption", data=train_set, scatter_kws={'color':'orange'}, line_kws={'color':'black'})
# Out:
# <Axes: xlabel='Number of Occupants', ylabel='Energy Consumption'>

# %%
import seaborn as sns
sns.regplot(x="Appliances Used", y="Energy Consumption", data=train_set, scatter_kws={'color':'gray'}, line_kws={'color':'black'})
# Out:
# <Axes: xlabel='Appliances Used', ylabel='Energy Consumption'>

# %%
import seaborn as sns
sns.regplot(x="Average Temperature", y="Energy Consumption", data=train_set, scatter_kws={'color':'red'}, line_kws={'color':'black'})
# Out:
# <Axes: xlabel='Average Temperature', ylabel='Energy Consumption'>

# %% [markdown]
# ## Data Preprocessing

# %%
train_set.head()
# Out:
#   Building Type  Square Footage  Number of Occupants  Appliances Used  \
# 0   Residential            7063                   76               10
# 1    Commercial           44372                   66               45
# 2    Industrial           19255                   37               17
# 3   Residential           13265                   14               41
# 4    Commercial           13375                   26               18
#
#    Average Temperature Day of Week  Energy Consumption
# 0                29.84     Weekday             2713.95
# 1                16.72     Weekday             5744.99
# 2                14.30     Weekend             4101.24
# 3                32.82     Weekday             3009.14
# 4                11.92     Weekday             3279.17

# %%
## convert the categorical attributes into numerical values
train_set.replace({'Building Type':{'Residential':1,'Commercial':2,'Industrial':3},'Day of Week':{'Weekday':1,'Weekend':2}}, inplace=True)
train_set.head()
# Out:
# C:\Users\THIS PC\AppData\Local\Temp\ipykernel_53804\3796975501.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   train_set.replace({'Building Type':{'Residential':1,'Commercial':2,'Industrial':3},'Day of Week':{'Weekday':1,'Weekend':2}}, inplace=True)
#    Building Type  Square Footage  Number of Occupants  Appliances Used  \
# 0              1            7063                   76               10
# 1              2           44372                   66               45
# 2              3           19255                   37               17
# 3              1           13265                   14               41
# 4              2           13375                   26               18
#
#    Average Temperature  Day of Week  Energy Consumption
# 0                29.84            1             2713.95
# 1                16.72            1             5744.99
# 2                14.30            2             4101.24
# 3                32.82            1             3009.14
# 4                11.92            1             3279.17

# %%
## check the value counts of categorical attributes

# %%
train_set['Building Type'].value_counts()
# Out:
# Building Type
# 1    347
# 2    336
# 3    317
# Name: count, dtype: int64

# %%
train_set['Day of Week'].value_counts()
# Out:
# Day of Week
# 1    507
# 2    493
# Name: count, dtype: int64

# %% [markdown]
# ## Seperate the independant and target variables

# %%
x=train_set.drop('Energy Consumption', axis=True)
x.head()
# Out:
#    Building Type  Square Footage  Number of Occupants  Appliances Used  \
# 0              1            7063                   76               10
# 1              2           44372                   66               45
# 2              3           19255                   37               17
# 3              1           13265                   14               41
# 4              2           13375                   26               18
#
#    Average Temperature  Day of Week
# 0                29.84            1
# 1                16.72            1
# 2                14.30            2
# 3                32.82            1
# 4                11.92            1

# %%
x.keys()
# Out:
# Index(['Building Type', 'Square Footage', 'Number of Occupants',
#        'Appliances Used', 'Average Temperature', 'Day of Week'],
#       dtype='object')

# %%
y=train_set['Energy Consumption']
y.head()
# Out:
# 0    2713.95
# 1    5744.99
# 2    4101.24
# 3    3009.14
# 4    3279.17
# Name: Energy Consumption, dtype: float64

# %%
## scale the data set

# %%
from sklearn.preprocessing import StandardScaler
std_scaler=StandardScaler()
scaled_train_data=std_scaler.fit_transform(x)
scaled_train_data=pd.DataFrame(scaled_train_data, columns=x.keys())
scaled_train_data.head()
# Out:
#    Building Type  Square Footage  Number of Occupants  Appliances Used  \
# 0      -1.191193       -1.287805             0.951134        -1.106957
# 1       0.036841        1.323516             0.606869         1.375645
# 2       1.264875       -0.434466            -0.391498        -0.610436
# 3      -1.191193       -0.853716            -1.183306         1.091919
# 4       0.036841       -0.846017            -0.770188        -0.539505
#
#    Average Temperature  Day of Week
# 0             1.012925    -0.986097
# 1            -0.825544    -0.986097
# 2            -1.164652     1.014099
# 3             1.430504    -0.986097
# 4            -1.498155    -0.986097

# %%
## create the pickle file including the scaler object
import pickle 
pickle.dump(std_scaler,open('scaler.pkl','wb'))

# %%
scaled_train_data_corr=scaled_train_data.corr()
scaled_train_data_corr
# Out:
#                      Building Type  Square Footage  Number of Occupants  \
# Building Type             1.000000        0.009403             0.025922
# Square Footage            0.009403        1.000000             0.033379
# Number of Occupants       0.025922        0.033379             1.000000
# Appliances Used           0.024841       -0.013478             0.023646
# Average Temperature      -0.006448        0.027273             0.014122
# Day of Week               0.026504        0.011354             0.014296
#
#                      Appliances Used  Average Temperature  Day of Week
# Building Type               0.024841            -0.006448     0.026504
# Square Footage             -0.013478             0.027273     0.011354
# Number of Occupants         0.023646             0.014122     0.014296
# Appliances Used             1.000000            -0.062870    -0.009046
# Average Temperature        -0.062870             1.000000    -0.011106
# Day of Week                -0.009046            -0.011106     1.000000

# %% [markdown]
# ## Split the train set into train and test set

# %%
from sklearn.model_selection import train_test_split

X_train, X_test,y_train,y_test=train_test_split(scaled_train_data,y,test_size=0.2,random_state=42)
X_train.head()
# Out:
#      Building Type  Square Footage  Number of Occupants  Appliances Used  \
# 29       -1.191193        0.112660            -1.252159         0.311673
# 535       0.036841       -1.091058            -1.493144        -0.468573
# 695       1.264875       -0.212452            -1.389864        -0.894162
# 557      -1.191193        0.326624            -0.666909         0.524467
# 836       0.036841       -0.637792            -1.183306         0.879125
#
#      Average Temperature  Day of Week
# 29              1.440313     1.014099
# 535            -0.274844    -0.986097
# 695             0.504263    -0.986097
# 557             0.156748     1.014099
# 836            -0.591532    -0.986097

# %%
X_test.head()
# Out:
#      Building Type  Square Footage  Number of Occupants  Appliances Used  \
# 521       0.036841        1.030951            -0.873468        -0.184847
# 737      -1.191193       -1.193806            -0.804615         0.737262
# 740       1.264875        1.557778             1.501957        -1.319751
# 660       0.036841        0.837984            -0.770188         0.666330
# 411       0.036841       -0.989080            -0.047233         1.233782
#
#      Average Temperature  Day of Week
# 521             1.035345     1.014099
# 737            -0.438793    -0.986097
# 740             1.430504     1.014099
# 660            -0.136118    -0.986097
# 411            -0.211787     1.014099

# %%
y_train.head()
# Out:
# 29     3409.14
# 535    2870.44
# 695    3880.32
# 557    3837.78
# 836    3675.54
# Name: Energy Consumption, dtype: float64

# %%
## check the shape of X_trai,X_test,y_train,_test

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((800, 6), (200, 6), (800,), (200,))

# %% [markdown]
# ## Model Training

# %%
from sklearn.linear_model import LinearRegression
linear_model=LinearRegression()
linear_model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
## Print the coefficient and  intercept
print(linear_model.coef_)
# Out:
# [407.15489846 714.36997828 290.47446888 281.96245827 -35.68270051
#  -24.99810003]

# %%
print(linear_model.intercept_)
# Out:
# 4166.2524278555875

# %%
## Linear regression model use defualt parameters
linear_model.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %% [markdown]
# ## Model testing

# %%
## test the model using X_test

# %%
reg_pred=linear_model.predict(X_test)
reg_pred
# Out:
# array([4549.59815272, 2842.90113058, 5781.84782711, 4773.55048601,
#        3791.05013191, 2470.59937902, 5003.04933675, 3314.09976596,
#        5147.09995484, 4298.90003823, 2998.54927358, 3915.70123054,
#        5329.29811039, 4628.79938672, 4682.44982574, 3658.95142562,
#        3446.14845112, 5088.19900965, 4534.04885268, 5338.1504149 ,
#        4073.00047768, 4978.70001197, 4354.25178473, 3439.35128913,
#        2512.09917757, 3699.84819791, 3796.70215174, 2683.75022723,
#        5359.0997317 , 4802.20165426, 4828.19861854, 4315.74840798,
#        3973.34931939, 6053.70143835, 4023.40135426, 5543.65041699,
#        3870.29839525, 3987.84963881, 3522.90027484, 4923.24947667,
#        3708.10006218, 2728.6501491 , 4302.79880501, 4860.79870273,
#        5247.04993391, 4261.0497435 , 3437.75042938, 4749.65084612,
#        2260.79916861, 4847.1000024 , 4566.39924379, 5340.40021699,
#        5842.69793411, 5744.85194301, 3930.14881638, 4230.10221237,
#        4496.55067015, 4318.60061377, 2514.39922387, 4534.85057076,
#        2318.1512844 , 2417.0982622 , 2372.14970307, 4318.79897649,
#        4934.79905761, 3679.95103146, 3549.49974355, 4449.54934268,
#        6133.65005003, 2839.20047624, 4172.09795514, 3631.5507002 ,
#        5096.29954562, 4722.8997746 , 3932.54993316, 4908.05093841,
#        4495.20045695, 5038.35017343, 2521.64863895, 4785.25053992,
#        4314.54864085, 3403.94965044, 3809.7003793 , 4722.70003884,
#        3707.15188747, 4164.49918392, 3245.00053877, 4655.19847195,
#        5327.65202674, 4258.49849958, 3689.05073266, 3519.5995711 ,
#        5454.75090515, 3955.14958934, 2906.54833996, 4330.6000715 ,
#        4546.15158732, 2497.70149452, 2968.2004387 , 4813.60028224,
#        4245.5484739 , 4787.64924208, 2667.44847983, 5074.25139801,
#        3937.59918465, 4612.20008731, 3509.85030416, 4207.14982644,
#        4212.09907454, 4449.6491764 , 3888.9002689 , 5390.74809496,
#        5262.74980685, 5107.00031955, 4805.1499148 , 3985.79998224,
#        5718.19802461, 5348.29829506, 4082.40016369, 3386.70143598,
#        5332.50035939, 3375.60156676, 3900.35094055, 3390.54874681,
#        4558.05093618, 4082.54885603, 4085.94960873, 4879.39810772,
#        3350.05142426, 4935.70035679, 3540.45084807, 4103.10138679,
#        2130.25015185, 3661.19965403, 4876.10011001, 5505.94957514,
#        6041.70007214, 4600.2998457 , 4812.14892187, 2451.64960029,
#        6493.50188561, 5369.94956494, 2500.09921842, 4516.30159745,
#        4620.94823748, 4988.55010906, 5156.69856503, 3984.19849614,
#        2556.64945178, 3933.39947312, 4684.94807951, 3028.5509468 ,
#        3427.99943329, 4945.09951083, 4678.74854451, 2276.7006504 ,
#        4141.80041077, 4798.24943331, 4027.55272132, 5518.15081087,
#        4958.54868064, 3838.75248594, 3558.80078633, 4772.79990068,
#        3060.90096649, 5709.24835331, 5332.10105009, 4676.25085169,
#        5437.14764738, 3631.10085243, 3891.84884748, 4724.75195784,
#        3811.7496206 , 4979.85052958, 3765.04809542, 3510.30004364,
#        5367.9004869 , 4114.45157923, 4634.35122132, 4712.34932314,
#        4002.69835775, 4015.04806225, 4253.39888675, 4149.50126475,
#        4378.54951919, 5015.5997794 , 4988.45123089, 3459.60179182,
#        4796.84888597, 4018.04955939, 4518.94827406, 5393.95086347,
#        5563.50141534, 4227.15091316, 3019.10167794, 2619.35037304,
#        3510.49912101, 3768.30024324, 3949.40071077, 4944.40144989])

# %%
## plot the reg_pred and  y_test in scatterplot
plt.scatter(y_test,reg_pred, color='purple')
plt.xlabel('reg_pred')
plt.ylabel('y_test')
plt.show()

# %%
## calculate the residuals

# %%
residuals=y_test-reg_pred
residuals
# Out:
# 521   -0.008153
# 737    0.008869
# 740   -0.017827
# 660   -0.010486
# 411   -0.010132
#          ...
# 408    0.009627
# 332    0.020879
# 208   -0.000243
# 613   -0.000711
# 78    -0.001450
# Name: Energy Consumption, Length: 200, dtype: float64

# %%
## plot the  residuals
sns.displot(residuals,kind='kde')

# %%
## Scatterplot for predictions vs residuals
plt.scatter(reg_pred,residuals, color='red')
plt.xlabel('residuals')
plt.ylabel('reg_pred')
plt.show()

# %%
## Evaluvate the model using evaluvation metrics

# %%
## mean squared error
from sklearn.metrics import mean_squared_error
linear_model_mse=mean_squared_error(y_test,reg_pred)
linear_model_mse
# Out:
# 0.00018845875691129817

# %%
## mean absolute error
from sklearn.metrics import mean_absolute_error
linear_model_mae=mean_absolute_error(y_test,reg_pred)
linear_model_mae
# Out:
# 0.011410743180410918

# %%
## root means squared error
linear_model_rmse=np.sqrt(linear_model_mse)
linear_model_rmse
# Out:
# 0.013728028150877975

# %%
## R Squared and Adjusted R squared

# %% [markdown]
# ###### R^2=1-SSR/SST

# %%
from sklearn.metrics  import r2_score
score=r2_score(y_test,reg_pred)
print(score)
# Out:
# 0.9999999997685636

# %% [markdown]
# ##### Adjusted R2=1-[(1-R^2)*(n-1)/(n-k-1)]

# %%
adjusted_r2_score=1-(1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
adjusted_r2_score
# Out:
# 0.9999999997613687

# %% [markdown]
# ## Testing

# %%
## Load the test data
test_set=pd.read_csv("test_energy_data.csv")
test_set.head(5)
# Out:
#   Building Type  Square Footage  Number of Occupants  Appliances Used  \
# 0   Residential           24563                   15                4
# 1    Commercial           27583                   56               23
# 2    Commercial           45313                    4               44
# 3   Residential           41625                   84               17
# 4   Residential           36720                   58               47
#
#    Average Temperature Day of Week  Energy Consumption
# 0                28.52     Weekday             2865.57
# 1                23.07     Weekend             4283.80
# 2                33.56     Weekday             5067.83
# 3                27.39     Weekend             4624.30
# 4                17.08     Weekday             4820.59

# %%
### check the type of the test dataset
type(test_set)
# Out:
# pandas.core.frame.DataFrame

# %%
## check the features of the test dataset
test_set.keys()
# Out:
# Index(['Building Type', 'Square Footage', 'Number of Occupants',
#        'Appliances Used', 'Average Temperature', 'Day of Week',
#        'Energy Consumption'],
#       dtype='object')

# %%
## check the information of test dataset
test_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Building Type        100 non-null    object
#  1   Square Footage       100 non-null    int64
#  2   Number of Occupants  100 non-null    int64
#  3   Appliances Used      100 non-null    int64
#  4   Average Temperature  100 non-null    float64
#  5   Day of Week          100 non-null    object
#  6   Energy Consumption   100 non-null    float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 5.6+ KB

# %%
## check the missing values of test_set
test_set.isnull().sum()
# Out:
# Building Type          0
# Square Footage         0
# Number of Occupants    0
# Appliances Used        0
# Average Temperature    0
# Day of Week            0
# Energy Consumption     0
# dtype: int64

# %% [markdown]
# ## Data Preprocessing for test set

# %%
test_set.head()
# Out:
#   Building Type  Square Footage  Number of Occupants  Appliances Used  \
# 0   Residential           24563                   15                4
# 1    Commercial           27583                   56               23
# 2    Commercial           45313                    4               44
# 3   Residential           41625                   84               17
# 4   Residential           36720                   58               47
#
#    Average Temperature Day of Week  Energy Consumption
# 0                28.52     Weekday             2865.57
# 1                23.07     Weekend             4283.80
# 2                33.56     Weekday             5067.83
# 3                27.39     Weekend             4624.30
# 4                17.08     Weekday             4820.59

# %%
## convert the categorical attributes into numerical values
test_set.replace({'Building Type':{'Residential':1,'Commercial':2,'Industrial':3},'Day of Week':{'Weekday':1,'Weekend':2}}, inplace=True)
test_set.head()
# Out:
# C:\Users\THIS PC\AppData\Local\Temp\ipykernel_53804\776146987.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   test_set.replace({'Building Type':{'Residential':1,'Commercial':2,'Industrial':3},'Day of Week':{'Weekday':1,'Weekend':2}}, inplace=True)
#    Building Type  Square Footage  Number of Occupants  Appliances Used  \
# 0              1           24563                   15                4
# 1              2           27583                   56               23
# 2              2           45313                    4               44
# 3              1           41625                   84               17
# 4              1           36720                   58               47
#
#    Average Temperature  Day of Week  Energy Consumption
# 0                28.52            1             2865.57
# 1                23.07            2             4283.80
# 2                33.56            1             5067.83
# 3                27.39            2             4624.30
# 4                17.08            1             4820.59

# %%
## Drop the target column
test_set=test_set.drop('Energy Consumption', axis=1)
test_set.head()
# Out:
#    Building Type  Square Footage  Number of Occupants  Appliances Used  \
# 0              1           24563                   15                4
# 1              2           27583                   56               23
# 2              2           45313                    4               44
# 3              1           41625                   84               17
# 4              1           36720                   58               47
#
#    Average Temperature  Day of Week
# 0                28.52            1
# 1                23.07            2
# 2                33.56            1
# 3                27.39            2
# 4                17.08            1

# %%
## scale the dataset

# %%
scaled_test_set=std_scaler.transform(test_set)
scaled_test_set_pd=pd.DataFrame(scaled_test_set, columns=test_set.keys())
scaled_test_set_pd.head()
# Out:
#    Building Type  Square Footage  Number of Occupants  Appliances Used  \
# 0      -1.191193       -0.062950            -1.148879        -1.532546
# 1       0.036841        0.148425             0.262605        -0.184847
# 2       0.036841        1.389378            -1.527570         1.304714
# 3      -1.191193        1.131249             1.226545        -0.610436
# 4      -1.191193        0.787940             0.331458         1.517508
#
#    Average Temperature  Day of Week
# 0             0.827957    -0.986097
# 1             0.064264     1.014099
# 2             1.534198    -0.986097
# 3             0.669613     1.014099
# 4            -0.775098    -0.986097

# %%
scaled_test_set_pd.head()
# Out:
#    Building Type  Square Footage  Number of Occupants  Appliances Used  \
# 0      -1.191193       -0.062950            -1.148879        -1.532546
# 1       0.036841        0.148425             0.262605        -0.184847
# 2       0.036841        1.389378            -1.527570         1.304714
# 3      -1.191193        1.131249             1.226545        -0.610436
# 4      -1.191193        0.787940             0.331458         1.517508
#
#    Average Temperature  Day of Week
# 0             0.827957    -0.986097
# 1             0.064264     1.014099
# 2             1.534198    -0.986097
# 3             0.669613     1.014099
# 4            -0.775098    -0.986097

# %%
##  make the predictions

# %%
predictions =linear_model.predict(scaled_test_set_pd)
predictions
# Out:
# array([2865.54923504, 4283.79931601, 5067.84899727, 4624.29837416,
#        4820.60115946, 5026.25059305, 4404.54909315, 2394.34994771,
#        3969.09941276, 5136.70219697, 5162.34992393, 3810.10150425,
#        4400.49912368, 4991.65066235, 4475.00108002, 2668.05033655,
#        4987.49984323, 4039.99980149, 3388.30117033, 4068.94800971,
#        4379.8495189 , 4921.7492881 , 5116.90030581, 4656.29919905,
#        5508.64982836, 4205.3496181 , 4275.6497535 , 4491.94851418,
#        3999.14950992, 3758.94893899, 4779.10086119, 4603.84967612,
#        6042.55127896, 3509.64971368, 3598.85033827, 4003.54979685,
#        4193.34874579, 3907.99793522, 2405.35005269, 5611.20010885,
#        4789.34960653, 3840.20060044, 4897.65071666, 4428.84928173,
#        4276.25045501, 3506.65093055, 5172.75061997, 2731.84917141,
#        3163.45076528, 4149.10234308, 3160.2491014 , 4294.59958523,
#        5275.90104247, 3072.64836669, 3629.60183181, 5014.79926973,
#        2998.44945786, 4983.44904825, 4707.05133452, 2872.04867807,
#        2351.94889471, 5161.94850509, 3562.44874042, 2725.9019455 ,
#        5346.04988737, 5446.00006159, 4575.60094077, 4046.89968408,
#        3039.49917373, 3843.99907098, 4103.39916694, 4721.4013858 ,
#        5334.3513661 , 4510.20186662, 4009.79982007, 3375.05220325,
#        4618.74974861, 4939.05105799, 3112.65052714, 4612.05080489,
#        3980.90145635, 4374.35033905, 4050.79986695, 5900.29901478,
#        3694.5004826 , 4652.64935013, 5016.10138576, 3127.79825858,
#        5179.49955626, 4001.95034198, 3451.59937966, 3977.64961193,
#        3830.69955274, 4250.30014028, 4137.64836159, 3010.80060943,
#        4248.49909186, 2843.60053489, 3348.40112636, 4722.59926476])

# %%
## Make the predictions based on the user data

# %%
user_data = [[0.036841,0.148425,0.262605,-0.184847,0.064264,1.014099]]
predictions = linear_model.predict(user_data)
predictions
# Out:
# C:\Users\THIS PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([4283.79925757])

# %% [markdown]
# ## Pickling the model file for deployment

# %%
import pickle

# %%
pickle.dump(linear_model, open('regression.pkl', 'wb'))

# %%
## Load the  pickle file
pickled_model=pickle.load(open('regression.pkl','rb'))
pickled_model
# Out:
# LinearRegression()

# %%
pickled_model_predictions = linear_model.predict(user_data)
predictions
# Out:
# C:\Users\THIS PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([4283.79925757])
